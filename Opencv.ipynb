# %%
import cv2

# %%
image=cv2.imread("/content/drive/MyDrive/dataset/ele.jpg")

# %%
image.shape
# Out:
# (406, 406, 3)

# %%
image
# Out:
# array([[[ 37,  76,  51],
#         [ 27,  66,  41],
#         [ 20,  59,  37],
#         ...,
#         [ 20,  39,  22],
#         [ 22,  41,  24],
#         [ 27,  46,  29]],
#
#        [[ 41,  81,  56],
#         [ 32,  72,  47],
#         [ 27,  66,  44],
#         ...,
#         [ 23,  42,  25],
#         [ 24,  43,  26],
#         [ 29,  48,  31]],
#
#        [[ 44,  86,  61],
#         [ 38,  80,  55],
#         [ 34,  76,  53],
#         ...,
#         [ 29,  48,  31],
#         [ 30,  49,  32],
#         [ 35,  54,  37]],
#
#        ...,
#
#        [[ 77, 166, 133],
#         [ 73, 167, 133],
#         [ 72, 168, 138],
#         ...,
#         [ 35, 210, 183],
#         [ 48, 210, 185],
#         [ 52, 210, 186]],
#
#        [[ 73, 160, 127],
#         [ 73, 162, 129],
#         [ 69, 161, 132],
#         ...,
#         [ 28, 208, 180],
#         [ 37, 208, 182],
#         [ 44, 208, 183]],
#
#        [[ 75, 160, 128],
#         [ 77, 164, 131],
#         [ 69, 161, 132],
# ...

# %%
image=cv2.cvtColor(image,cv2.COLOR_BGR2RGB)

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(20,20))

# %%
plt.subplot(2,2,1)
# Out:
# <Axes: >

# %%
plt.imshow(image)

# %%
image_Scaled=cv2.resize(image,None,fx=2,fy=2,interpolation=cv2.INTER_CUBIC)

# %%
plt.imshow(image_Scaled)

# %%
img_scaled=cv2.resize(image,(900,400),interpolation=cv2.INTER_AREA)

# %%
plt.imshow(img_scaled)

# %%
import numpy as np
kernel_sharpening=np.array([[-1,-1,-1],[-1,9,-1],[-1,-1,-1]])

# %%
sharpned=cv2.filter2D(image,-1,kernel_sharpening)

# %%
plt.imshow(sharpned)

# %%
plt.imshow(image)

# %%
kernel_blue=np.ones((3,3),np.float32)/9

# %%
blur=cv2.filter2D(image,kernel_blue)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-30-47a8dd3fd466> in <cell line: 1>()
# ----> 1 blur=cv2.filter2D(image,kernel_blue)
#
# error: OpenCV(4.7.0) :-1: error: (-5:Bad argument) in function 'filter2D'
# > Overload resolution failed:
# >  - filter2D() missing required argument 'kernel' (pos 3)
# >  - filter2D() missing required argument 'kernel' (pos 3)

# %%
image= cv2.copyMakeBorder(image,100,100,50,50,cv2.BORDER_REFLECT)

# %%
plt.matshow(image)
